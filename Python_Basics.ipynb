# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScientist2807/python/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(data={"a":[4,5,6], "b":[4,5,6], "c":[4,5,6]}, index=[1,2,3])

# %%
df = pd.read_excel("Matchplan_Python_Basics.xlsx")

# %%
df
# Out:
#   Hometeam Awayteam  hthg  htag  fthg  ftag  Unnamed: 6  Unnamed: 7  \
# 0   Bayner   Bayern     2     1     2     2         NaN         NaN
# 1   Bayern      BVB     2     3     3     3         NaN         NaN
# 2  Schalke      BVB     2     4     2     5         NaN         NaN
# 3  Schalke  Schalke     4     4     6     4         NaN         NaN
# 4   Bayern  Schalke     0     2     0     4         NaN         NaN
# 5      BVB  Schalke     3     0     3     2         NaN         NaN
# 6   Bayner      BVB     1     4     3     5         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11 Unnamed: 12
# 0         NaN         NaN          NaN          NaN         NaN
# 1         NaN         NaN          NaN          NaN         NaN
# 2         NaN         NaN          NaN          0.0         BVB
# 3         NaN         NaN          NaN          1.0     Schalke
# 4         NaN         NaN          NaN          2.0      Bayner
# ...
